# %%
import pandas as pd
import numpy as np

# %%
d1=pd.read_csv('dataset.csv')

# %%
d2=pd.read_csv('Symptom-severity.csv')

# %%
d3=pd.read_csv('symptom_Description.csv')

# %%
d4=pd.read_csv("symptom_precaution.csv")

# %%
cols=['Disease','Symptom_1','Symptom_2','Symptom_3']

# %%
df=pd.DataFrame(data=d1,columns=cols)

# %%
df
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3
# 0                 skin_rash   nodal_skin_eruptions
# ...

# %%
def get_weights(symptom):
    ind=int(d2[d2['Symptom']==symptom].index.values)
    return d2.iloc[ind]['weight']

# %%
def remove_space(string):
    return string.replace(" ", "")

# %%
w1=[]
w2=[]
w3=[]
s=[]
for i in range(4920):
    s1=remove_space(df.iloc[i]['Symptom_1'])
    s2=remove_space(df.iloc[i]['Symptom_2'])
    s3=remove_space(df.iloc[i]['Symptom_3'])
    w1.append(get_weights(s1))
    w2.append(get_weights(s2))
    w3.append(get_weights(s3))

# %%
df['sw_1']=w1
df['sw_2']=w2
df['sw_3']=w3

# %%
df
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3  sw_1  sw_2  sw_3
# 0                 skin_rash   nodal_skin_eruptions     1     3     4
# ...

# %%
l1=list(set(list(d1['Symptom_1'])))
l2=list(set(list(d1['Symptom_2'])))
l3=list(set(list(d1['Symptom_3'])))

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['Symptom_1']= le.fit_transform(df['Symptom_1']) 
df['Symptom_2']= le.fit_transform(df['Symptom_2']) 
df['Symptom_3']= le.fit_transform(df['Symptom_3'])

# %%
df
# Out:
#                                       Disease  Symptom_1  Symptom_2  \
# 0                            Fungal infection         33         35
# 1                            Fungal infection         24         27
# 2                            Fungal infection         33         27
# 3                            Fungal infection         33         35
# 4                            Fungal infection         33         35
# ...                                       ...        ...        ...
# 4915  (vertigo) Paroymsal  Positional Vertigo         28         17
# 4916                                     Acne         24         31
# 4917                  Urinary tract infection          4          4
# 4918                                Psoriasis         24         20
# 4919                                 Impetigo         24         18
#
#       Symptom_3  sw_1  sw_2  sw_3
# 0            35     1     3     4
# 1            18     3     4     6
# 2            18     1     4     6
# ...

# %% [markdown]
# # dictionary

# %%
dic1={}
dic2={}
dic3={}
for i in range(4920):
    dic1[remove_space(d1.iloc[i]['Symptom_1'])]=df.iloc[i]['Symptom_1']
    dic2[remove_space(d1.iloc[i]['Symptom_2'])]=df.iloc[i]['Symptom_2']
    dic3[remove_space(d1.iloc[i]['Symptom_3'])]=df.iloc[i]['Symptom_3']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
cols_to_normalize=['Symptom_1','Symptom_2','Symptom_3','sw_1','sw_2','sw_3']

# %%
x=df[cols_to_normalize].values

# %%
x_scaled = scaler.fit_transform(x)

# %%
df_temp = pd.DataFrame(x_scaled, columns=cols_to_normalize, index = df.index)

# %%
df_temp
# Out:
#       Symptom_1  Symptom_2  Symptom_3      sw_1      sw_2      sw_3
# 0      1.456441   0.576959   0.536238 -1.831804 -0.965576 -0.138636
# 1      0.576999   0.004191  -0.612902 -0.312250 -0.137362  1.462514
# 2      1.456441   0.004191  -0.612902 -1.831804 -0.137362  1.462514
# 3      1.456441   0.576959  -0.612902 -1.831804 -0.965576  1.462514
# 4      1.456441   0.576959   0.536238 -1.831804 -0.965576 -0.138636
# ...         ...        ...        ...       ...       ...       ...
# 4915   0.967862  -0.711769   0.401045  1.207304 -0.965576  0.661939
# 4916   0.576999   0.290575  -1.626849 -0.312250 -1.793789 -1.739786
# 4917  -1.377315  -1.642517  -0.342516  1.967081 -0.137362  0.661939
# 4918   0.576999  -0.496981   1.009413 -0.312250 -0.965576 -0.939211
# 4919   0.576999  -0.640173  -1.559252 -0.312250  2.347278 -0.138636
#
# [4920 rows x 6 columns]

# %%
le_y=LabelEncoder()
df['Disease']= le_y.fit_transform(df['Disease'])

# %%
le_y
# Out:
# LabelEncoder()

# %%
df
# Out:
#       Disease  Symptom_1  Symptom_2  Symptom_3  sw_1  sw_2  sw_3
# 0          15         33         35         35     1     3     4
# 1          15         24         27         18     3     4     6
# 2          15         33         27         18     1     4     6
# 3          15         33         35         18     1     3     6
# 4          15         33         35         35     1     3     4
# ...       ...        ...        ...        ...   ...   ...   ...
# 4915        0         28         17         33     5     3     5
# 4916        2         24         31          3     3     2     2
# 4917       38          4          4         22     6     4     5
# 4918       35         24         20         42     3     3     3
# 4919       27         24         18          4     3     7     4
#
# [4920 rows x 7 columns]

# %%
x=df_temp[cols_to_normalize]
y=df['Disease']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators = 1000)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
predictions = rf.predict(x_test)
actual=y_test
predictions=list(predictions.reshape(-1,1))
predicted=[]
for i in predictions:
    for j in i:
        predicted.append(round(j))
actual=list(actual)
count=0
for i in range(len(actual)):
    if(actual[i]==predicted[i]):
        count+=1
accuracy_rf=count/len(actual)
print(str(round((accuracy_rf*100),2))+' %')
# Out:
# 81.57 %

# %%
def random_forest_predict(l):
    for i in (rf.predict([l])):
        return int(i)

# %%
def rfp(pre):
    final=[]
    wts=[]
    for i in pre:
        wts.append(get_weights(i))
    # small fix needed
    pre[0]=dic1[pre[0]]
    pre[1]=dic2[pre[1]]
    pre[2]=dic3[pre[2]]
    final=pre+wts
    sc=StandardScaler().fit(df[cols_to_normalize])
    final=list((sc.transform([final]))[0])
    #numerical=int(random_forest_predict(final))
    #f=le_y.inverse_transform([numerical])[0]
    numerical=random_forest_predict(final)
    return (le_y.inverse_transform([numerical])[0])

# %%
rfp(['itching','skin_rash','nodal_skin_eruptions'])
# Out:
# 'Fungal infection'

# %%
rfp(['skin_rash','bladder_discomfort','foul_smell_ofurine'])
# Out:
# 'Dimorphic hemmorhoids(piles)'

# %%
def precautions(string):
    ind=int(d4[d4['Disease']==string].index.values)
    p1=d4.iloc[0]['Precaution_1']
    p2=d4.iloc[0]['Precaution_2']
    p3=d4.iloc[0]['Precaution_3']
    print(str(p1)+'\n'+str(p2)+'\n'+str(p3))

# %%
precautions('Drug Reaction')
# Out:
# stop irritation
# consult nearest hospital
# stop taking drug

# %%
from sklearn import neighbors
classifier=neighbors.KNeighborsClassifier()
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score
predictions=classifier.predict(x_test)
expected=y_test

# %%
accuracy_knn=accuracy_score(y_test,predictions)
print(str(round((accuracy_knn*100),2))+' %')
# Out:
# 93.5 %

# %%
def knn_predict(l):
    return (int(classifier.predict([l])))

# %%
def knnp(pre):
    final=[]
    wts=[]
    for i in pre:
        wts.append(get_weights(i))
    # small fix needed
    pre[0]=dic1[pre[0]]
    pre[1]=dic2[pre[1]]
    pre[2]=dic3[pre[2]]
    final=pre+wts
    sc=StandardScaler().fit(df[cols_to_normalize])
    final=list((sc.transform([final]))[0])
    numerical=knn_predict(final)
    return (le_y.inverse_transform([numerical])[0])

# %%
precautions(knnp(['itching','skin_rash','nodal_skin_eruptions']))
# Out:
# stop irritation
# consult nearest hospital
# stop taking drug

# %%
precautions(knnp(['skin_rash','bladder_discomfort','foul_smell_ofurine']))
# Out:
# stop irritation
# consult nearest hospital
# stop taking drug

# %%
def about(string):
    ind=int(d3[d3['Disease']==string].index.values)
    print(d3.iloc[ind]['Description'])

# %%
about(knnp(['skin_rash','bladder_discomfort','foul_smell_ofurine']))
# Out:
# Gastroenteritis is an inflammation of the digestive tract, particularly the stomach, and large and small intestines. Viral and bacterial gastroenteritis are intestinal infections associated with symptoms of diarrhea , abdominal cramps, nausea , and vomiting .

# %% [markdown]
# # Pickle

# %%
#file = open('knn_model.pkl', 'wb')
#pickle.dump(classifier,file)

# %% [markdown]
# import pickle
#
# le_y=le_y.fit_transform(d1['Disease'])
# label_encoder= open('label_encoder_y.pkl', 'wb')
# pickle.dump(le_y,label_encoder)

# %%
cols_to_normalize
# Out:
# ['Symptom_1', 'Symptom_2', 'Symptom_3', 'sw_1', 'sw_2', 'sw_3']

# %%
df
# Out:
#       Disease  Symptom_1  Symptom_2  Symptom_3  sw_1  sw_2  sw_3
# 0          15         33         35         35     1     3     4
# 1          15         24         27         18     3     4     6
# 2          15         33         27         18     1     4     6
# 3          15         33         35         18     1     3     6
# 4          15         33         35         35     1     3     4
# ...       ...        ...        ...        ...   ...   ...   ...
# 4915        0         28         17         33     5     3     5
# 4916        2         24         31          3     3     2     2
# 4917       38          4          4         22     6     4     5
# 4918       35         24         20         42     3     3     3
# 4919       27         24         18          4     3     7     4
#
# [4920 rows x 7 columns]

# %%
df.to_csv('data')

# %%
le_y.inverse_transform([17])[0]
# Out:
# 'Gastroenteritis'

# %%
df
# Out:
#       Disease  Symptom_1  Symptom_2  Symptom_3  sw_1  sw_2  sw_3
# 0          15         33         35         35     1     3     4
# 1          15         24         27         18     3     4     6
# 2          15         33         27         18     1     4     6
# 3          15         33         35         18     1     3     6
# 4          15         33         35         35     1     3     4
# ...       ...        ...        ...        ...   ...   ...   ...
# 4915        0         28         17         33     5     3     5
# 4916        2         24         31          3     3     2     2
# 4917       38          4          4         22     6     4     5
# 4918       35         24         20         42     3     3     3
# 4919       27         24         18          4     3     7     4
#
# [4920 rows x 7 columns]

# %%
d1
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
le_y
# Out:
# LabelEncoder()

# %%
df
# Out:
#       Disease  Symptom_1  Symptom_2  Symptom_3  sw_1  sw_2  sw_3
# 0          15         33         35         35     1     3     4
# 1          15         24         27         18     3     4     6
# 2          15         33         27         18     1     4     6
# 3          15         33         35         18     1     3     6
# 4          15         33         35         35     1     3     4
# ...       ...        ...        ...        ...   ...   ...   ...
# 4915        0         28         17         33     5     3     5
# 4916        2         24         31          3     3     2     2
# 4917       38          4          4         22     6     4     5
# 4918       35         24         20         42     3     3     3
# 4919       27         24         18          4     3     7     4
#
# [4920 rows x 7 columns]

# %%
d1
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
ly=LabelEncoder()

# %%
encoded_y = ly.fit_transform(d1['Disease'])

# %%
encoded_y
# Out:
# array([15, 15, 15, ..., 38, 35, 27])

# %%
ly.inverse_transform([15])
# Out:
# array(['Fungal infection'], dtype=object)

# %%
d1
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-3075b36c09c8> in <module>
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined

# %%
about('Hypertension')

# %%
precautions('Hypertension ')

# %%
d4.iloc[14]['Disease']

# %%
for i in range(d4.shape[0]):
    d4.iloc[i]['Disease']=d4.iloc[i]['Disease'].strip()

# %%
for i in range(d3.shape[0]):
    d3.iloc[i]['Disease']=d3.iloc[i]['Disease'].strip()

# %%
d3
